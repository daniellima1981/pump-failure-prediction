# %%
import pandas as pd
from pathlib import Path

# Path absoluto baseado na raiz do projeto
ROOT_DIR = Path("C:/git/pump-failure-prediction")

df_test_sample = pd.read_csv(
    ROOT_DIR / "data" / "processed" / "dataset_merged.csv"
)[["Pressure - leak line", "Temperature - leak line",
   "Pressure - output", "Temperature - output",
   "Flow - leak line", "Flow - output", "Temp. diff"]].sample(200, random_state=42)

df_test_sample.to_csv(
    ROOT_DIR / "data" / "sample_input.csv",
    index=False
)

print("✅ Arquivo de teste gerado!")
print(f"   Path: {ROOT_DIR / 'data' / 'sample_input.csv'}")
print(f"   Shape: {df_test_sample.shape}")
print(f"\nPrimeiras linhas:")
print(df_test_sample.head(3))
# Out:
# ✅ Arquivo de teste gerado!
#    Path: C:\git\pump-failure-prediction\data\sample_input.csv
#    Shape: (200, 7)
#
# Primeiras linhas:
#         Pressure - leak line  Temperature - leak line  Pressure - output  \
# 133999              0.201346                56.253846         145.371346
# 86461               0.232642                45.115849         194.155849
# 56844               0.176222                50.015556         210.310889
#
#         Temperature - output  Flow - leak line  Flow - output  Temp. diff
# 133999             47.475577          2.831731      63.391346   10.521923
# 86461              30.075283          2.631321      62.124151   17.623019
# 56844              37.990444          1.866222      62.896444   15.118000
