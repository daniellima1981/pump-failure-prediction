# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.data.preprocessor import run_preprocessing_pipeline
from src.features.engineer import run_feature_engineering

# Etapa 3 — gera X_test e y_test
X_train, X_val, X_test, y_train, y_val, y_test = run_preprocessing_pipeline()

# Etapa 4 — aplica feature engineering
X_train, X_val, X_test = run_feature_engineering(X_train, X_val, X_test)

# Etapa 6 — avaliação no teste (carrega modelo do MLflow)
from src.models.evaluator import run_evaluation

run_evaluation(
    X_test=X_test,
    y_test=y_test,
    model_name="XGBoost_Tuned"
)
# Out:
# INFO:src.data.preprocessor: Starting pre-processing pipeline...
#
# INFO:src.data.preprocessor:Removed Columns: ['Czas', 'Czas2', 'label_name', 'stan']
# INFO:src.data.preprocessor:Shape after removal: (153205, 9)
# INFO:src.data.preprocessor:Redundat columns removed: ['Temperature - suction line']
# INFO:src.data.preprocessor:Shape after removal: (153205, 8)
# INFO:src.data.preprocessor:
#  Nan found:
# INFO:src.data.preprocessor:Flow - output    6846
# INFO:src.data.preprocessor:  'Flow - output': 6846 NaN → filled with median (63.1859)
# INFO:src.data.preprocessor:
#  NaN treated. Total filled: 6846
# INFO:src.data.preprocessor:
# Outliers clipped (threshold=3.0 std):
# INFO:src.data.preprocessor:  Pressure - leak line: 309 adjusted values
# INFO:src.data.preprocessor:
# Dataset Split:
# INFO:src.data.preprocessor:  Train:      107,243 samples (70.0%)
# INFO:src.data.preprocessor:  Validation:  22,981  samples (15.0%)
# INFO:src.data.preprocessor:  Test:        22,981 samples (15.0%)
# INFO:src.data.preprocessor:Trained Scaler and save in: C:\git\pump-failure-prediction\models\scaler.joblib
# INFO:src.data.preprocessor: Scaler loaded and applied from: C:\git\pump-failure-prediction\models\scaler.joblib
# INFO:src.data.preprocessor: Scaler loaded and applied from: C:\git\pump-failure-prediction\models\scaler.joblib
# INFO:src.data.preprocessor:
# Distribution before SMOTE:
# INFO:src.data.preprocessor:label
# 0    47843
# 1    37837
# 2    10033
# 3    11530
# INFO:src.data.preprocessor:Distribution after SMOTE:
# INFO:src.data.preprocessor:label
# 0    47843
# 1    47843
# 2    47843
# 3    47843
# INFO:src.data.preprocessor:Amostras adicionadas: 84,129
# INFO:src.data.preprocessor:
# Pipeline Finished!
# INFO:src.data.preprocessor:  X_train: (191372, 7)
# INFO:src.data.preprocessor:  X_val:   (22981, 7)
# INFO:src.data.preprocessor:  X_test:  (22981, 7)
# INFO:src.features.engineer: Starting Feature Engineering...
#
# INFO:src.features.engineer:--- Processing train ---
# INFO:src.features.engineer:Created ratio features: 3
# INFO:src.features.engineer: Rolling features created: 24 (4 sensors × 3 window × 2 statistics)
# INFO:src.features.engineer:Delta features created: 3
# INFO:src.features.engineer:--- Processing val ---
# INFO:src.features.engineer:Created ratio features: 3
# INFO:src.features.engineer: Rolling features created: 24 (4 sensors × 3 window × 2 statistics)
# INFO:src.features.engineer:Delta features created: 3
# INFO:src.features.engineer:--- Processing test ---
# INFO:src.features.engineer:Created ratio features: 3
# INFO:src.features.engineer: Rolling features created: 24 (4 sensors × 3 window × 2 statistics)
# INFO:src.features.engineer:Delta features created: 3
# INFO:src.features.engineer:
#  Feature Engineering Finished !
# INFO:src.features.engineer:  Original Features: 7
# INFO:src.features.engineer:     Final Features:    37
# INFO:src.features.engineer:   Created Features:   30
# INFO:src.features.engineer:
#   Full List:
#   ['Pressure - leak line', 'Temperature - leak line', 'Pressure - output', 'Temperature - output', 'Flow - leak line', 'Flow - output', 'Temp. diff', 'ratio_flow_leak_output', 'ratio_pressure_leak_output', 'ratio_temp_diff_output', 'pressure__leak_line_mean_5s', 'pressure__leak_line_std_5s', 'pressure__leak_line_mean_10s', 'pressure__leak_line_std_10s', 'pressure__leak_line_mean_30s', 'pressure__leak_line_std_30s', 'temperature__leak_line_mean_5s', 'temperature__leak_line_std_5s', 'temperature__leak_line_mean_10s', 'temperature__leak_line_std_10s', 'temperature__leak_line_mean_30s', 'temperature__leak_line_std_30s', 'flow__leak_line_mean_5s', 'flow__leak_line_std_5s', 'flow__leak_line_mean_10s', 'flow__leak_line_std_10s', 'flow__leak_line_mean_30s', 'flow__leak_line_std_30s', 'flow__output_mean_5s', 'flow__output_std_5s', 'flow__output_mean_10s', 'flow__output_std_10s', 'flow__output_mean_30s', 'flow__output_std_30s', 'pressure__output_delta', 'pressure__leak_line_delta', 'flow__output_delta']
# INFO:src.models.evaluator: Starting final evaluationg at test set...
#
# INFO:src.models.evaluator: Model loaded: models:/PumpFailurePredictor_XGBoost_Tuned/latest
# INFO:src.models.evaluator:
#  Test Metrics — XGBoost_Tuned:
# INFO:src.models.evaluator:  test_f1_macro: 0.9972
# INFO:src.models.evaluator:  test_f1_weighted: 0.9983
# INFO:src.models.evaluator:  test_roc_auc: 1.0000
# INFO:src.models.evaluator:  test_accuracy: 0.9983
# INFO:src.models.evaluator:  test_f1_normal: 0.9994
# INFO:src.models.evaluator:  test_f1_desgaste: 0.9988
# INFO:src.models.evaluator:  test_f1_falha1: 0.9949
# INFO:src.models.evaluator:  test_f1_falha2: 0.9956
# INFO:src.models.evaluator:
#  Classification Report (TEST):
#                         precision    recall  f1-score   support
#
#                 Normal       1.00      1.00      1.00     10252
# Desgaste (Valve Plate)       1.00      1.00      1.00      8108
#        Falha Forçada 1       0.99      1.00      0.99      2150
#        Falha Forçada 2       0.99      1.00      1.00      2471
#
#               accuracy                           1.00     22981
#              macro avg       1.00      1.00      1.00     22981
#           weighted avg       1.00      1.00      1.00     22981
#
# INFO:src.models.evaluator: ROC curves recorded at: C:\git\pump-failure-prediction\reports\roc_curves_XGBoost_Tuned.png
# INFO:src.models.evaluator:
#  Avaliation finished and recorded into MLflow!
# INFO:src.models.evaluator: Access http://127.0.0.1:5000 to visulize

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.models.persistor import run_persistence_pipeline

run_persistence_pipeline()
# Out:
# INFO:src.models.persistor: Starting the pipeline persistence...
#
# INFO:src.models.persistor: Model loaded from Registry: models:/PumpFailurePredictor_XGBoost_Tuned/latest
# INFO:src.models.persistor: Model exported to: C:\git\pump-failure-prediction\models\xgboost_model.joblib
# INFO:src.models.persistor:
#  Validanting artefacts...
# INFO:src.models.persistor:  scaler: sucessfully loaded → StandardScaler
# INFO:src.models.persistor:     → 7 features escalated
# INFO:src.models.persistor:  model: sucessfully loaded → XGBClassifier
# INFO:src.models.persistor:     → method 'predict'
# INFO:src.models.persistor:     → method 'predict_proba'
# INFO:src.models.persistor:
#  All artefacts validated — dashboard done to run!
# INFO:src.models.persistor:
#  Metadata saved in: C:\git\pump-failure-prediction\models\model_metadata.json
# INFO:src.models.persistor:   Expected Features (7):
# INFO:src.models.persistor:   → Pressure - leak line
# INFO:src.models.persistor:   → Temperature - leak line
# INFO:src.models.persistor:   → Pressure - output
# INFO:src.models.persistor:   → Temperature - output
# INFO:src.models.persistor:   → Flow - leak line
# INFO:src.models.persistor:   → Flow - output
# INFO:src.models.persistor:   → Temp. diff
# INFO:src.models.persistor:
#  Pipeline persistece concluded!
# INFO:src.models.persistor:
#  Artefacts done for the dashboard:
# INFO:src.models.persistor:  C:\git\pump-failure-prediction\models\scaler.joblib
# INFO:src.models.persistor:  C:\git\pump-failure-prediction\models\xgboost_model.joblib
# INFO:src.models.persistor:  C:\git\pump-failure-prediction\models\model_metadata.json

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.data.preprocessor import run_preprocessing_pipeline
from src.features.engineer import run_feature_engineering

# Etapas 3 e 4 — para ter X_train na memória
X_train, X_val, X_test, y_train, y_val, y_test = run_preprocessing_pipeline()
X_train, X_val, X_test = run_feature_engineering(X_train, X_val, X_test)

# Agora salva os metadados com as 37 features
from src.models.persistor import save_model_metadata
save_model_metadata(feature_names=X_train.columns.tolist())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# INFO:src.data.preprocessor: Starting pre-processing pipeline...
#
# INFO:src.data.preprocessor:Removed Columns: ['Czas', 'Czas2', 'label_name', 'stan']
# INFO:src.data.preprocessor:Shape after removal: (153205, 9)
# INFO:src.data.preprocessor:Redundat columns removed: ['Temperature - suction line']
# INFO:src.data.preprocessor:Shape after removal: (153205, 8)
# INFO:src.data.preprocessor:
#  Nan found:
# INFO:src.data.preprocessor:Flow - output    6846
# INFO:src.data.preprocessor:  'Flow - output': 6846 NaN → filled with median (63.1859)
# INFO:src.data.preprocessor:
#  NaN treated. Total filled: 6846
# INFO:src.data.preprocessor:
# Outliers clipped (threshold=3.0 std):
# INFO:src.data.preprocessor:  Pressure - leak line: 309 adjusted values
# INFO:src.data.preprocessor:
# Dataset Split:
# INFO:src.data.preprocessor:  Train:      107,243 samples (70.0%)
# INFO:src.data.preprocessor:  Validation:  22,981  samples (15.0%)
# INFO:src.data.preprocessor:  Test:        22,981 samples (15.0%)
# INFO:src.data.preprocessor:Trained Scaler and save in: C:\git\pump-failure-prediction\models\scaler.joblib
# INFO:src.data.preprocessor: Scaler loaded and applied from: C:\git\pump-failure-prediction\models\scaler.joblib
# INFO:src.data.preprocessor: Scaler loaded and applied from: C:\git\pump-failure-prediction\models\scaler.joblib
# INFO:src.data.preprocessor:
# Distribution before SMOTE:
# INFO:src.data.preprocessor:label
# 0    47843
# 1    37837
# 2    10033
# 3    11530
# INFO:src.data.preprocessor:Distribution after SMOTE:
# INFO:src.data.preprocessor:label
# 0    47843
# 1    47843
# 2    47843
# 3    47843
# INFO:src.data.preprocessor:Amostras adicionadas: 84,129
# INFO:src.data.preprocessor:
# Pipeline Finished!
# INFO:src.data.preprocessor:  X_train: (191372, 7)
# INFO:src.data.preprocessor:  X_val:   (22981, 7)
# INFO:src.data.preprocessor:  X_test:  (22981, 7)
# INFO:src.features.engineer: Starting Feature Engineering...
#
# INFO:src.features.engineer:--- Processing train ---
# INFO:src.features.engineer:Created ratio features: 3
# INFO:src.features.engineer: Rolling features created: 24 (4 sensors × 3 window × 2 statistics)
# INFO:src.features.engineer:Delta features created: 3
# INFO:src.features.engineer:--- Processing val ---
# INFO:src.features.engineer:Created ratio features: 3
# INFO:src.features.engineer: Rolling features created: 24 (4 sensors × 3 window × 2 statistics)
# INFO:src.features.engineer:Delta features created: 3
# INFO:src.features.engineer:--- Processing test ---
# INFO:src.features.engineer:Created ratio features: 3
# INFO:src.features.engineer: Rolling features created: 24 (4 sensors × 3 window × 2 statistics)
# INFO:src.features.engineer:Delta features created: 3
# INFO:src.features.engineer:
#  Feature Engineering Finished !
# INFO:src.features.engineer:  Original Features: 7
# INFO:src.features.engineer:     Final Features:    37
# INFO:src.features.engineer:   Created Features:   30
# INFO:src.features.engineer:
#   Full List:
#   ['Pressure - leak line', 'Temperature - leak line', 'Pressure - output', 'Temperature - output', 'Flow - leak line', 'Flow - output', 'Temp. diff', 'ratio_flow_leak_output', 'ratio_pressure_leak_output', 'ratio_temp_diff_output', 'pressure__leak_line_mean_5s', 'pressure__leak_line_std_5s', 'pressure__leak_line_mean_10s', 'pressure__leak_line_std_10s', 'pressure__leak_line_mean_30s', 'pressure__leak_line_std_30s', 'temperature__leak_line_mean_5s', 'temperature__leak_line_std_5s', 'temperature__leak_line_mean_10s', 'temperature__leak_line_std_10s', 'temperature__leak_line_mean_30s', 'temperature__leak_line_std_30s', 'flow__leak_line_mean_5s', 'flow__leak_line_std_5s', 'flow__leak_line_mean_10s', 'flow__leak_line_std_10s', 'flow__leak_line_mean_30s', 'flow__leak_line_std_30s', 'flow__output_mean_5s', 'flow__output_std_5s', 'flow__output_mean_10s', 'flow__output_std_10s', 'flow__output_mean_30s', 'flow__output_std_30s', 'pressure__output_delta', 'pressure__leak_line_delta', 'flow__output_delta']
# INFO:src.models.persistor:
#  Metadata saved: C:\git\pump-failure-prediction\models\model_metadata.json
# INFO:src.models.persistor:   Model features (37):
# INFO:src.models.persistor:   → Pressure - leak line
# INFO:src.models.persistor:   → Temperature - leak line
# INFO:src.models.persistor:   → Pressure - output
# INFO:src.models.persistor:   → Temperature - output
# INFO:src.models.persistor:   → Flow - leak line
# INFO:src.models.persistor:   → Flow - output
# INFO:src.models.persistor:   → Temp. diff
# INFO:src.models.persistor:   → ratio_flow_leak_output
# INFO:src.models.persistor:   → ratio_pressure_leak_output
# INFO:src.models.persistor:   → ratio_temp_diff_output
# INFO:src.models.persistor:   → pressure__leak_line_mean_5s
# INFO:src.models.persistor:   → pressure__leak_line_std_5s
# INFO:src.models.persistor:   → pressure__leak_line_mean_10s
# INFO:src.models.persistor:   → pressure__leak_line_std_10s
# INFO:src.models.persistor:   → pressure__leak_line_mean_30s
# INFO:src.models.persistor:   → pressure__leak_line_std_30s
# INFO:src.models.persistor:   → temperature__leak_line_mean_5s
# INFO:src.models.persistor:   → temperature__leak_line_std_5s
# INFO:src.models.persistor:   → temperature__leak_line_mean_10s
# INFO:src.models.persistor:   → temperature__leak_line_std_10s
# INFO:src.models.persistor:   → temperature__leak_line_mean_30s
# INFO:src.models.persistor:   → temperature__leak_line_std_30s
# INFO:src.models.persistor:   → flow__leak_line_mean_5s
# INFO:src.models.persistor:   → flow__leak_line_std_5s
# INFO:src.models.persistor:   → flow__leak_line_mean_10s
# INFO:src.models.persistor:   → flow__leak_line_std_10s
# INFO:src.models.persistor:   → flow__leak_line_mean_30s
# INFO:src.models.persistor:   → flow__leak_line_std_30s
# INFO:src.models.persistor:   → flow__output_mean_5s
# INFO:src.models.persistor:   → flow__output_std_5s
# INFO:src.models.persistor:   → flow__output_mean_10s
# INFO:src.models.persistor:   → flow__output_std_10s
# INFO:src.models.persistor:   → flow__output_mean_30s
# INFO:src.models.persistor:   → flow__output_std_30s
# INFO:src.models.persistor:   → pressure__output_delta
# INFO:src.models.persistor:   → pressure__leak_line_delta
# INFO:src.models.persistor:   → flow__output_delta
